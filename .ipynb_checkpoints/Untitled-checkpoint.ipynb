# %%
pip install faker
# Out:
# ...
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------- 2.1/2.1 MB 18.8 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import csv
import random
from datetime import datetime, timedelta

ROWS = 10_000_000

first_names = ["John","Mary","Alex","Sarah","David","Emma","Michael","Olivia","Daniel","Sophia"]
last_names = ["Smith","Johnson","Brown","Lee","Wilson","Martin","Clark","Young","Walker","King"]
departments = ["HR","Finance","Engineering","Sales","Marketing","Operations"]
provinces = ["ON","AB","BC","MB","SK","QC","NB","NS","PE","NL"]
statuses = ["Active","Terminated","Leave"]

with open("hr_fast.csv", "w", newline="", encoding="utf-8") as f:
    writer = csv.writer(f)
    writer.writerow([
        "employee_id","first_name","last_name","email","gender",
        "birth_date","hire_date","department","job_title","salary",
        "province","city","manager_id","status","created_at","updated_at"
    ])

    for i in range(1, ROWS + 1):
        first = random.choice(first_names)
        last = random.choice(last_names)
        email = f"{first.lower()}.{last.lower()}@example.com"

        birth_date = datetime(1970,1,1) + timedelta(days=random.randint(0,20000))
        hire_date = datetime(2000,1,1) + timedelta(days=random.randint(0,9000))

        writer.writerow([
            i,
            first,
            last,
            email,
            random.choice(["M","F"]),
            birth_date.date(),
            hire_date.date(),
            random.choice(departments),
            "Employee",
            random.randint(40000,180000),
            random.choice(provinces),
            "City",
            random.randint(1,5000),
            random.choice(statuses),
            datetime.now(),
            datetime.now()
        ])

# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\letov\Projects\hr_warehouse\hr_fast.csv")
df.head()
# Out:
#    employee_id first_name last_name                      email gender  \
# 0            1       Emma      King      emma.king@example.com      F
# 1            2       Alex    Walker    alex.walker@example.com      F
# 2            3     Daniel    Walker  daniel.walker@example.com      M
# 3            4    Michael     Brown  michael.brown@example.com      M
# 4            5      David   Johnson  david.johnson@example.com      F
#
#    birth_date   hire_date   department job_title  salary province  city  \
# 0  2010-08-27  2016-09-07           HR  Employee  112392       ON  City
# 1  1998-12-01  2002-10-22  Engineering  Employee  106578       NB  City
# 2  1995-02-16  2018-02-26   Operations  Employee   82156       SK  City
# 3  2018-06-20  2005-03-23        Sales  Employee  104134       AB  City
# 4  2019-09-11  2004-01-23    Marketing  Employee  168510       SK  City
#
#    manager_id      status                  created_at  \
# ...

# %%
df.columns
# Out:
# Index(['employee_id', 'first_name', 'last_name', 'email', 'gender',
#        'birth_date', 'hire_date', 'department', 'job_title', 'salary',
#        'province', 'city', 'manager_id', 'status', 'created_at', 'updated_at'],
#       dtype='object')
